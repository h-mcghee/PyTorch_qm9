# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
target_data = np.genfromtxt('/Users/harrymcghee/Desktop/CodingProjects/PyTorch_qm9/logs/target_data.txt')

fig,ax=plt.subplots()

x = target_data[:,0]
y = target_data[:,1]

ax.scatter(x,y, s=1)
ax.plot(x,x)

epoch_data = np.genfromtxt('/Users/harrymcghee/Desktop/CodingProjects/PyTorch_qm9/logs/epoch_data.txt')
x = epoch_data[:,0]
y = epoch_data[:,1]
fig,ax=plt.subplots()
ax.plot(x,'-x', label = 'train')
ax.plot(y,'-x', label = 'val')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
